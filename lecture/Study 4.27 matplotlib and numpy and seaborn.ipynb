# %% [markdown]
# # 6. 파이썬 라이브러리 활용 (01. 시각화 라이브러리)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
groupDataS02 = pd.read_csv('../exampleCode/dataset/st0002data.csv')

# %%
import matplotlib.pyplot as plt      # matplotlib 내 pyplot 시각화.
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
groupDataS01.head(3)
# Out:
#   REGIONID PRODUCTGROUP  WEEK  MEAN_VOLUME
# 0      A01       ST0001     1       559479
# 1      A01       ST0001     2       483233
# 2      A01       ST0001     3       457317

# %%
groupDataS02.head(3)
# Out:
#   REGIONID PRODUCTGROUP  WEEK  MEAN_VOLUME
# 0      A01       ST0002     1       158086
# 1      A01       ST0002     2       128312
# 2      A01       ST0002     3       127417

# %%
x = groupDataS01.WEEK                # set x-axis
y = groupDataS01.MEAN_VOLUME         # set y-axis

plt.plot(x,y)

# %%
plt.xticks(range(min(x),max(x),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격
plt.plot(x,y)

# %%
plt.xticks(range(0,max(x),5))
plt.plot(x,y)

# %%
plt.xticks(range(20,30,5))    # 눈금의 범위지 그래프의 범위는 아니다.
plt.plot(x,y)

# %%
# X, Y축 라벨
plt.xlabel("week")
plt.ylabel("avg_volume")

# 차트 제목
plt.title("weekly trend")

plt.plot(x,y)

# %%
plt.xticks(range(min(x),max(x),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격

# X, Y축 라벨
plt.xlabel("주")
plt.ylabel("평균")

# 차트 제목
plt.title("주간 경향")

plt.plot(x,y)

# %%
# 선색상, 종류, 굵기 변경
plt.plot(x,y, "bo-", lw=2.5)    # blue, o 점찍기, - 실선, # 굵기 2.5

# %%
plt.plot(x,y, "bo-", lw=0)    # 라인 굵기 0이라 점만 찍힘

# %%
plt.plot(x,y, "go-")    # green, o (점찍기)

# %%
plt.plot(x,y, "r")    # red

# %%
plt.plot(x,y, "--")    # 점선

# %%
plt.plot(x,y, "go--", lw=1)    # green, o, 점선

# %% [markdown]
# ### 만약 그래프 2개를 그리고 싶다면???

# %%
x = groupDataS01.WEEK                # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

plt.plot(x,y1)
plt.plot(x,y2)

# %%
x = groupDataS01.WEEK                # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

plt.xlabel("주간 경향")
plt.ylabel("평균 판매량")
plt.title("주간 판매 동향")

plt.xticks(range(min(x),max(x),5))

plt.plot(x,y1, label='st0001')
plt.plot(x,y2, label='st0002')
plt.legend(loc=0)                    # label을 붙일때면 이걸 항상 써줘야한다. 0: 알아서, 1~4 : 각 사분면.

# %% [markdown]
# ## 실습문제 P.14

# %%
import pandas as pd

exampleData = pd.read_csv('../exampleCode/dataset/feature_regression_example.csv')
exampleData.head(3)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155

# %%
exampleData.tail(3)
# Out:
#            REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 104  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
# 105  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201710  2017    10
# 106  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201714  2017    14
#
#      QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 104  332       Y      1         Y     0.352361
# 105   14       N      4         N     0.000000
# 106    5       N      4         N     0.000000

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
x = exampleData.WEEK    # set x-axis
y = exampleData.QTY     # set y-axis

plt.xlabel('주')
plt.ylabel('판매량')
plt.title('미래예측')

plt.plot(x,y, label='QTY')
plt.legend(loc=0)

# %% [markdown]
# ### 모든게 다 나온다... (2015년 1-52주 갔다가 다시 2016년 1-52주 갔다가... 2017년까지 가서 이런 그래프가 나온다.)

# %%
exampleData2015 = exampleData.loc[exampleData.YEAR == 2015]    # 2015년 데이터만 가져온다.

# %% [raw]
# 만약 단순 년도가 아닌 주차 정보라면 이런 방법으로 가능하다.
# featuresData2015 = featuresData[ (featuresData.YEARWEEK >= 201501) &
#                                 (featuresData.YEARWEEK <= 201552)]
#
# featuresData2016 = featuresData[ (featuresData.YEARWEEK >= 201601) &
#                                 (featuresData.YEARWEEK <= 201652)]

# %%
exampleData2015.head(3)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155

# %%
exampleData2015.tail(3)
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 50  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201551  2015    51
# 51  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201552  2015    52
# 52  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201553  2015    53
#
#      QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 50   664       N      4         Y     0.237768
# 51  1082       Y      1         Y     0.237768
# 52  1750       Y      1         Y     0.237768

# %%
x = exampleData2015.WEEK    # set x-axis
y = exampleData2015.QTY     # set y-axis

plt.xlabel('주')
plt.ylabel('판매량')
plt.title('미래예측')

plt.plot(x,y, label='QTY')
plt.legend(loc=0)

# %%
x = exampleData2015.WEEK    # set x-axis
y = exampleData2015.QTY     # set y-axis
y2 = exampleData2015.PRO_PERCENT

plt.xlabel('주')
plt.ylabel('판매량')
plt.title('미래예측')

plt.yticks(range(min(y),max(y),500))

plt.plot(x,y, label='QTY')
plt.plot(x,y2, label='PRO_PERCENT')
plt.legend(loc=0)

# %% [markdown]
# 다시 처음 ST01, ST02로 가보자.

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
groupDataS02 = pd.read_csv('../exampleCode/dataset/st0002data.csv')

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# 데이터 확인

# %%
groupDataS01.head(3)
# Out:
#   REGIONID PRODUCTGROUP  WEEK  MEAN_VOLUME
# 0      A01       ST0001     1       559479
# 1      A01       ST0001     2       483233
# 2      A01       ST0001     3       457317

# %%
groupDataS02.head(3)
# Out:
#   REGIONID PRODUCTGROUP  WEEK  MEAN_VOLUME
# 0      A01       ST0002     1       158086
# 1      A01       ST0002     2       128312
# 2      A01       ST0002     3       127417

# %%
x1 = groupDataS01.WEEK               # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
x2 = groupDataS01.WEEK               # 또 다른 그래프의 x-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

plt.xlabel("주간 경향")
plt.ylabel("평균 판매량")
plt.title("주간 판매 동향")

plt.xticks(range(min(x),max(x),5))

plt.plot(x1,y1, label='st0001')
plt.plot(x2,y2, label='st0002')
plt.legend(loc=0)                    # label을 붙일때면 이걸 항상 써줘야한다. 0: 알아서, 1~4 : 각 사분면.

# %% [markdown]
# 이대로 그냥 실행하면 안 되고, 이제 이 2개의 도표와 그래프를 그려줄 공간을 만들고, 저 각각의 그래프를 배치하는 작업이 필요합니다.

# %%
# 도화지 만들기
paper = plt.figure(figsize=(14,4))    # (가로,세로)로 그려지고 1 = 72픽셀.

# %%
# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(121)         # 1x2 matrix의 1번째.
chart2 = paper.add_subplot(122)         # 1x2 matrix의 2번째.

# %%
# 이제 chart1과 chart2에 각각의 그래프에 대한 정보를 넣어줍니다. 단일 도표에 그래프를 2개 그리는 것과 달리 약간의 문법이 추가됩니다.
# plt는 모두 chart1, chart2로 바꾸고, 라벨과 제목은 앞에 set_을 붙여주면 됩니다.
# 서로 다른 2개의 그래프를 단지 하나의 도화지에 그리는 것 뿐이니 당연히 라벨도 모두 2개씩 필요하겠죠? 열심히 복붙하고 고쳐줍니다.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x),max(x),5))

chart1.plot(x1,y1, label='st0001')
chart1.legend(loc=0)
# chart1.grid(True)


chart2.set_xlabel("주간 경향")
chart2.set_ylabel("평균 판매량")
chart2.set_title("주간 판매 동향")
chart2.set_xticks(range(min(x),max(x),5))

chart2.plot(x2,y2, label='st0002')
chart2.legend(loc=0)
# chart2.grid(True)

# %% [markdown]
# 완성된 모습은 다음과 같습니다.

# %%
x1 = groupDataS01.WEEK               # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
x2 = groupDataS01.WEEK               # 또 다른 그래프의 x-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

# %%
# 도화지 만들기
paper = plt.figure(figsize=(14,4))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(121)         # 1x2 matrix의 1번째.
chart2 = paper.add_subplot(122)         # 1x2 matrix의 2번째.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x1),max(x1),5))

chart1.plot(x1,y1, label='st0001')
chart1.legend(loc=0)
# chart1.grid(True)


chart2.set_xlabel("주간 경향")
chart2.set_ylabel("평균 판매량")
chart2.set_title("주간 판매 동향")
chart2.set_xticks(range(min(x2),max(x2),5))

chart2.plot(x2,y2, label='st0002')
chart2.legend(loc=0)
# chart2.grid(True)

# %% [markdown]
# 만약 그래프를 세로로 배치하고 싶다면 도화지의 가로세로 크기를 조정하고 <br>
# (그래프의 크기를 동일하게 하려면 가로는 1/2배, 세로는 2배를 하면 된다.(figsize=(7,8)), <br>
# matrix를 2x1로 만들어주고 1번째, 2번째에 넣어주면 됩니다. 즉, (211), (212).

# %%
# 도화지 만들기
paper = plt.figure(figsize=(7,8))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(211)         # 2x1 matrix의 1번째.
chart2 = paper.add_subplot(212)         # 2x2 matrix의 2번째.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x2),max(x2),5))

chart1.plot(x1,y1, label='st0001')
chart1.legend(loc=0)
chart1.grid(True)


chart2.set_xlabel("주간 경향")
chart2.set_ylabel("평균 판매량")
chart2.set_title("주간 판매 동향")
chart2.set_xticks(range(min(x2),max(x2),5))

chart2.plot(x2,y2, label='st0002')
chart2.legend(loc=0)
chart2.grid(True)

# %% [markdown]
# 만약 하나의 도화지 위에 2개의 그래프를 겹쳐 y축을 각각 따로 그려주고 싶다면 이렇게 하면 됩니다.<br>
# 이 경우 x축을 공유할거라 x값은 하나만 선언해주면 되겠죠?

# %%
x1 = groupDataS01.WEEK               # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

# %%
# 도화지 만들기
paper = plt.figure(figsize=(14,6))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(111)         # 1x1 matrix의 1번째.
chart2 = chart1.twinx()                 # chart2의 그래프를 그리는게 아니라 chart1에 join 시켜줍니다.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x1),max(x1),5))

chart1.plot(x1,y1, 'b', label='st0001') # 색상을 적절히 정해줍니다.
chart1.legend(loc=1)
chart1.grid(True)

# 아래 값들은 모두 중복되는 것이니 지워줍니다.
# chart2.set_xlabel("주간 경향")
# chart2.set_ylabel("평균 판매량")
# chart2.set_title("주간 판매 동향")
# chart2.set_xticks(range(min(x2),max(x2),5))

chart2.plot(x1,y2, 'g', label='st0002') # 색상을 적절히 정해줍니다.
chart2.legend(loc=4)
# chart2.grid(True)                     # 모눈종이를 그릴 경우 2개의 모눈종이가 모두 그려지면 지저분해지니 하나만 그려줍니다.

# %% [markdown]
# # 완성본 모음

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
# groupDataS01.head(3)

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x = groupDataS01.WEEK                # set x-axis
y = groupDataS01.MEAN_VOLUME         # set y-axis

# 차트 꾸미기
plt.xlabel("주")
plt.ylabel("평균")
plt.title("주간 경향")
plt.xticks(range(min(x),max(x),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격

# 차트 그리기
plt.plot(x,y, 'bo-', lw=0.8, label='MEAN_VOLUME')
plt.legend(loc=0)
plt.grid(True)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
# groupDataS01.head(3)

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x = groupDataS01.WEEK                # set x-axis
y = groupDataS01.MEAN_VOLUME         # set y-axis

# 차트 꾸미기
plt.xlabel("주")
plt.ylabel("평균")
plt.title("주간 경향")
plt.xticks(range(min(x),max(x),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격

# 차트 그리기
plt.bar(x,y, color='blue', width=0.5, label='MEAN_VOLUME')
plt.legend(loc=0)
plt.grid(True)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
# groupDataS01.head(3)

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x = groupDataS01.WEEK                # set x-axis
y = groupDataS01.MEAN_VOLUME         # set y-axis



# 도화지 만들기
paper = plt.figure(figsize=(14,6))

# 도화지에 chart1의 공간을 만듭니다.
chart1 = paper.add_subplot(111)

# 차트 꾸미기
chart1.set_xlabel("주")
chart1.set_ylabel("평균")
chart1.set_title("주간 경향")
chart1.set_xticks(range(min(x),max(x),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격

# 차트 그리기
chart1.bar(x,y, width=0.6, label='MEAN_VOLUME')    # bar 그래프는 그냥 'b', lw=0.5 만 쓰면 안 됨.
chart1.legend(loc=0)
chart1.grid(False)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
# groupDataS01.head(3)

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x = groupDataS01.WEEK                # set x-axis
y = groupDataS01.MEAN_VOLUME         # set y-axis

# 도화지 만들기
paper = plt.figure(figsize=(14,6))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(111)

plt.xticks(range(min(x),max(x),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격

# 차트 꾸미기
plt.xlabel("주")
plt.ylabel("평균")
plt.title("주간 경향")

# 차트 그리기
plt.bar(x,y, label='MEAN_VOLUME')
plt.grid(True)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
groupDataS02 = pd.read_csv('../exampleCode/dataset/st0002data.csv')

# groupDataS01.head(3)
# groupDataS02.head(3)


import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x1 = groupDataS01.WEEK               # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
x2 = groupDataS01.WEEK               # 또 다른 그래프의 x-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

# 도화지 만들기
paper = plt.figure(figsize=(14,4))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(121)         # 2x1 matrix의 1번째.
chart2 = paper.add_subplot(122)         # 2x2 matrix의 2번째.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x2),max(x2),5))

chart1.plot(x1,y1, label='st0001')
chart1.legend(loc=0)
chart1.grid(True)


chart2.set_xlabel("주간 경향")
chart2.set_ylabel("평균 판매량")
chart2.set_title("주간 판매 동향")
chart2.set_xticks(range(min(x2),max(x2),5))

chart2.plot(x2,y2, label='st0002')
chart2.legend(loc=0)
chart2.grid(True)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
groupDataS02 = pd.read_csv('../exampleCode/dataset/st0002data.csv')

# groupDataS01.head(3)
# groupDataS02.head(3)


import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x1 = groupDataS01.WEEK               # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
x2 = groupDataS01.WEEK               # 또 다른 그래프의 x-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

# 도화지 만들기
paper = plt.figure(figsize=(7,10))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(211)         # 2x1 matrix의 1번째.
chart2 = paper.add_subplot(212)         # 2x2 matrix의 2번째.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x2),max(x2),5))

chart1.plot(x1,y1, label='st0001')
chart1.legend(loc=0)
chart1.grid(True)


chart2.set_xlabel("주간 경향")
chart2.set_ylabel("평균 판매량")
chart2.set_title("주간 판매 동향")
chart2.set_xticks(range(min(x2),max(x2),5))

chart2.plot(x2,y2, label='st0002')
chart2.legend(loc=0)
chart2.grid(True)

# %%
import pandas as pd

groupDataS01 = pd.read_csv('../exampleCode/dataset/st0001data.csv')
groupDataS02 = pd.read_csv('../exampleCode/dataset/st0002data.csv')

# groupDataS01.head(3)
# groupDataS02.head(3)


import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False


x1 = groupDataS01.WEEK               # set x-axis
y1 = groupDataS01.MEAN_VOLUME        # set y-axis
x2 = groupDataS01.WEEK               # 또 다른 그래프의 x-axis
y2 = groupDataS02.MEAN_VOLUME        # 또 다른 그래프의 y-axis

# 도화지 만들기
paper = plt.figure(figsize=(14,6))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(111)         # 1x1 matrix의 1번째.
chart2 = chart1.twinx()                 # chart2의 그래프를 그리는게 아니라 chart1에 join 시켜줍니다.

chart1.set_xlabel("주간 경향")
chart1.set_ylabel("평균 판매량")
chart1.set_title("주간 판매 동향")
chart1.set_xticks(range(min(x1),max(x1),5))

chart1.plot(x1,y1, 'b', label='st0001') # 색상을 적절히 정해줍니다.
chart1.legend(loc=1)
chart1.grid(True)

chart2.plot(x1,y2, 'g', label='st0002') # 색상을 적절히 정해줍니다.
chart2.legend(loc=4)
# chart2.grid(True)                     # 모눈종이를 그릴 경우 2개의 모눈종이가 모두 그려지면 지저분해지니 하나만 그려줍니다.

# %%
type(exampleData2015['PRO_PERCENT'][0])
# Out:
# numpy.float64

# %%
import pandas as pd

exampleData = pd.read_csv('../exampleCode/dataset/feature_regression_example.csv')
# exampleData.head(3)

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

exampleData2015 = exampleData[exampleData.YEAR == 2015]    # 2015년 데이터만 가져온다.

x = exampleData2015.WEEK    # set x-axis
y = exampleData2015.QTY     # set y-axis
y2 = exampleData2015.PRO_PERCENT

# 도화지 만들기
paper = plt.figure(figsize=(14,6))

# 도화지에 chart1과 chart2의 공간을 만듭니다.
chart1 = paper.add_subplot(111)
chart2 = chart1.twinx()

chart1.set_xlabel('주')
chart1.set_ylabel('판매량')
chart1.set_title('미래예측')

chart1.plot(x,y, 'b', label='QTY')
chart1.legend(loc=2)

chart2.plot(x,y2, 'c', label='PRO_PERCENT')
chart2.legend(loc=1)

# %%
# 필요 라이브러리 정의
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

# 라벨 및 값 정의
groupLabel = ['A', 'B', 'C']
groupValue = [95, 54, 25]

# 파이차트 시각화
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.pie(x=groupValue,     
       labels=groupLabel,
       autopct="%1.2f%%",
       textprops={'fontsize': 12} )
ax1.legend(loc=0)

# %%
#필요 라이브러리 정의
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline
import numpy as np

x=list(range(1,11,1))
y = [i**2 for i in x]
c= np.random.randint(0,3,len(y))

plt.figure(figsize=(7,5))
plt.scatter(x,y,marker='o',c=c)
plt.colorbar()

plt.title('Scatter plt')
# Out:
# Text(0.5, 1.0, 'Scatter plt')

# %% [markdown]
# # Numpy

# %%
st1 = [100, 110, 90, 105, 95, 102, 98]
st2 = [100, 130, 70, 120, 80, 160, 40]
x = list (range(0, len(st1),))

import matplotlib.pyplot as plt

plt.plot(x,st1)
plt.plot(x,st2)

# %% [markdown]
# ### 평균은 같지만 그래프 모양은 많이 다르다.
# ### 평균, 분산, 표준편차를 구해보자.

# %%
import numpy as np

# 평균
st1Mean = np.mean(st1)
st2Mean = np.mean(st2)
print('st1 average : {}, st2 average : {}'.format(st1Mean, st2Mean))
# Out:
# st1 average : 100.0, st2 average : 100.0

# %%
import numpy as np

# 분산
st1Var = np.var(st1)
st2Var = np.var(st2)
print('st1 variance : {}, st2 variance : {}'.format(st1Var,st2Var))
# Out:
# st1 variance : 36.857142857142854, st2 variance : 1400.0

# %%
import numpy as np

# 표준편차 (= sqrt(분산))
st1Std = np.std(st1)
st2Std = np.std(st2)
print('st1 standard deviation : {}, st2 standard deviation : {}'.format(st1Std,st2Std))
# Out:
# st1 standard deviation : 6.07100838882165, st2 standard deviation : 37.416573867739416

# %% [markdown]
# ### Numpy 없이 구해보자.

# %%
# 분산
temp = 0
for _ in st1:
    temp = temp + (st1Mean - _) ** 2

st1Len = len(st1)
variance = temp / st1Len
variance
# Out:
# 36.857142857142854

# %%
# 표준편차 (= sqrt(분산))
standardDeviation = np.sqrt(variance)
standardDeviation
# Out:
# 6.07100838882165

# %%
# 표본표준편차. 얘는 함수가 없어서 이렇게 직접 해야한다. 아... 엑셀은 위대하다.
sampleStandardDeviation = np.sqrt(temp / (st1Len - 1))
sampleStandardDeviation
# Out:
# 6.557438524302
